# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # 1D example:

# %%
test1 = [1,2,3,4]
np.std(test1)
# Out:
# 1.118033988749895

# %%
import numpy as np
import matplotlib.pyplot as plt

# Set the random seed for reproducibility
np.random.seed(0)

# Generate 1000 data points from a normal distribution with mean 0 and standard deviation 1
x = np.random.normal(0, 1, 1000)


# Introduce an anomaly - a point that is much different than the rest
x[500] = 50

# A simple anomaly detection function
def detect_anomalies(data, threshold=3):
    # Calculate the mean and standard deviation of the data
    mean, std = np.mean(data), np.std(data)
    # Identify anomalies - points that are more than `threshold` standard deviations away from the mean
    anomalies = np.abs(data - mean) > threshold * std
    return anomalies

# Detect anomalies
anomalies = detect_anomalies(x)

# Plot the data and the anomalies
plt.figure(figsize=(10, 6))
plt.plot(x, 'b-')
plt.scatter(np.where(anomalies)[0], x[anomalies], color ='red')
plt.title('Data points and anomalies')
plt.xlabel('Index')
plt.ylabel('Value')
plt.grid(True)
plt.show()

    """In this code snippet:

We start by generating 1000 data points from a standard normal distribution (mean = 0, standard deviation = 1).

We then manually introduce an anomaly — a data point that is significantly different from the rest (in this case,
we set the 500th data point to 50).

The detect_anomalies function is a simple anomaly detection algorithm based on the statistical concept of 
a z-score. It calculates the mean and standard deviation of the data and flags data points that are more than
a certain threshold number of standard deviations away from the mean as anomalies. In this instance, we use a 
threshold of 3, which is a commonly used value, but this can be adjusted based on the specific context and requirements.
    """
#source: https://medium.com/@gabrielpierobon/guide-to-machine-learning-for-anomaly-detection-introduction-e9d0f810dec5

# %% [markdown]
# # 2D example, assuming independent features:

# %%
test1 = [1,2,3,4,56,6]
test2 = z_score(test1)
print (test2)
np.abs(test2) > 0.5
# Out:
# [-0.55724484 -0.50658622 -0.4559276  -0.40526898  2.22897937 -0.30395173]
# array([ True,  True, False, False,  True, False])

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generate a synthetic 2D dataset
np.random.seed(0)
x = np.random.normal(10, 2, 100)  # Dimension 1
y = np.random.normal(5, 1, 100)   # Dimension 2

data = np.vstack((x, y)).T

# Function to calculate z-score
def z_score(data):
    mean = np.mean(data)
    std = np.std(data)
    z_scores = (data - mean) / std
    return z_scores

# Calculate z-scores for each dimension
z_scores_x = z_score(data[:, 0])
z_scores_y = z_score(data[:, 1])

# Anomaly detection threshold (absolute z-score > 2 considered as an anomaly)
threshold = 2
# anomalies_x = np.where(np.abs(z_scores_x) > threshold)
# anomalies_y = np.where(np.abs(z_scores_y) > threshold)
anomalies_bool_x = np.abs(z_scores_x) > threshold
anomalies_bool_y = np.abs(z_scores_y) > threshold

# Combine anomalies using logical OR
all_anomalies_bool = anomalies_bool_x | anomalies_bool_y

# Find indices of combined anomalies
all_anomalies = np.where(all_anomalies_bool)[0]

# %%
[i for i in range(5)]
# Out:
# [0, 1, 2, 3, 4]

# %%
# Plot
plt.figure(figsize=(10, 6))
plt.scatter(x, y, label='Data Points')
plt.scatter(x[all_anomalies], y[all_anomalies], color='r', label='Anomalies found')
#plt.scatter(x[anomalies_y], y[anomalies_y], color='g', label='Anomalies in Y')
plt.xlabel('Dimension 1')
plt.ylabel('Dimension 2')
plt.title('Anomaly Detection using Z-Score')
plt.legend()
plt.show()


# # Set the random seed for reproducibility
# np.random.seed(0)

# # Generate 1000 data points from a normal distribution with mean 0 and standard deviation 1
# np.random.seed(0)
# x = np.random.normal(0, 1, 500)
# np.random.seed(1)
# y = np.random.normal(0, 1, 500)

# # Introduce an anomaly - a point that is much different than the rest
# x[50] = 50

# # A simple anomaly detection function
# def detect_anomalies(data, threshold=3):
#     # Calculate the mean and standard deviation of the data
#     mean, std = np.mean(data), np.std(data)
#     # Identify anomalies - points that are more than `threshold` standard deviations away from the mean
#     anomalies = np.abs(data - mean) > threshold * std
#     return anomalies

# # Detect anomalies
# data = [x,y]
# x_anomaly = detect_anomalies(x)
# y_anomaly = detect_anomalies(y)
# # Plot the data and the anomalies
# plt.figure(figsize=(10, 6))
# plt.scatter(x=x, y=y)
# plt.scatter(x = x[x_anomaly], y=y[y_anomaly])
# plt.title('Data points and anomalies')
# plt.xlabel('Index')
# plt.ylabel('Value')
# plt.grid(True)
# plt.show()
