# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import os
import sys

current_directory =  os.getcwd()
parent_directory = os.path.dirname(current_directory)
models_directory = os.path.join(parent_directory, 'src', 'models') 

sys.path.insert(0, models_directory) # defined root folder 1 step

# %%
np.random.seed(0)
np.random.random()
# Out:
# 0.5488135039273248

# %%
def get_normal_distribution():
    np.random.seed(45)
    return np.random.randn(50)

def get_index(data):
    return np.arange(len(data))


data = get_normal_distribution()
index = get_index(data)

# %%
from StatsMethods import get_z_score_outliers_1d, \
                         get_z_score_iter_outliers_1d, \
                         get_z_score_iter_outlier_plots, \
                         get_iqr_outliers_1d

# %%
get_iqr_outliers_1d(data)
# Out:
# array([False, False, False, False, False,  True, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False,  True, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False])

# %%
outliers_marked1 = get_z_score_outliers_1d(data, z_threshold = 2)
colors1 = ['red' if outlier else 'blue' for outlier in outliers_marked1]  

outliers_marked2 = get_z_score_iter_outliers_1d(data, z_threshold = 2)
colors2 = ['red' if outlier else 'blue' for outlier in outliers_marked2]  


fig, axs = plt.subplots(2,1)
axs[0].scatter(x=index, y=data,  color = colors1)
axs[1].scatter(x=index, y=data,  color = colors2)

plt.show

# %%
fig2 = get_z_score_iter_outlier_plots(data)

# %%
import numpy as np

def combine_outlier_booleans(*arg_bool):
    """gets any number of outlier_bool from different methods and 
    combines them. It is ment to be used to combine outliers found 
    from different methods to make a list of final outliers. 
    

    Returns:
        _type_: np.array(booleans)
    """
    combined_outlier_bool = np.array([False]*len(arg_bool[0]))
    for bool in arg_bool:
        combined_outlier_bool[bool]=True
    return combined_outlier_bool

ar1 = np.array([False, False, True])
ar2 = np.array([True, False, False])
ar3 = np.array([True, True, False])


combine_outlier_booleans(ar1,ar2, ar3)
# Out:
# array([ True,  True,  True])
